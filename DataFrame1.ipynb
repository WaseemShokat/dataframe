# %%
import pandas as pd
my_city_weather={
    'day':['1/1/2011','1/2/2011','1/3/2011'],
    'termprature':['75','65','35'],
    'event':['hot','hot','sunny'],
    'action':['inhome','inhome','outside']
}
df=pd.DataFrame(my_city_weather)
df
# Out:
#         day termprature  event   action
# 0  1/1/2011          75    hot   inhome
# 1  1/2/2011          65    hot   inhome
# 2  1/3/2011          35  sunny  outside

# %%
df.index
df.loc[1]
# Out:
# day            1/2/2011
# termprature          65
# event               hot
# action           inhome
# Name: 1, dtype: object

# %%
df.columns
# Out:
# Index(['day', 'termprature', 'event', 'action'], dtype='object')

# %%
pd.DataFrame(my_city_weather,index=['a','b','c'])
# Out:
#         day termprature  event   action
# a  1/1/2011          75    hot   inhome
# b  1/2/2011          65    hot   inhome
# c  1/3/2011          35  sunny  outside

# %%
pd.DataFrame(my_city_weather, index=['a', 'b', 'c'], columns=["day", "termprature","even"])
# Out:
#         day termprature even
# a  1/1/2011          75  NaN
# b  1/2/2011          65  NaN
# c  1/3/2011          35  NaN

# %%
pd.DataFrame(
    {
        ("a", "b"): {("A", "B"): 1, ("A", "C"): 2},
        ("a", "a"): {("A", "C"): 3, ("A", "B"): 4},
        ("a", "c"): {("A", "B"): 5, ("A", "C"): 6},
        ("b", "a"): {("A", "C"): 7, ("A", "B"): 8},
        ("b", "b"): {("A", "D"): 9, ("A", "B"): 10},
    }
)
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %%
pd.DataFrame(my_city_weather, index=['a', 'b', 'c'], columns=["day", "termprature","even"])
# Out:
#         day termprature even
# a  1/1/2011          75  NaN
# b  1/2/2011          65  NaN
# c  1/3/2011          35  NaN

# %%
my_city_weather["termprature"]
# Out:
# ['75', '65', '35']

# %%
df
# Out:
#         day termprature  event   action
# 0  1/1/2011          75    hot   inhome
# 1  1/2/2011          65    hot   inhome
# 2  1/3/2011          35  sunny  outside

# %%
df['day']
# Out:
# 0    1/1/2011
# 1    1/2/2011
# 2    1/3/2011
# Name: day, dtype: object

# %%
Temperature_report={
    'day':[1,2,3,4,5],
    'temperature':[34,38,32,31,33],
    'sale':[112,220,231,180,21],
    'spend':[21,41,24,34,19]
}
pf=pd.DataFrame(Temperature_report)
pf
# Out:
#    day  temperature  sale  spend
# 0    1           34   112     21
# 1    2           38   220     41
# 2    3           32   231     24
# 3    4           31   180     34
# 4    5           33    21     19

# %%
pf["Tcos"]=(pf["spend"]/pf["sale"])*100
pf["Alaram"]=pf["Tcos"]>20
pf
# Out:
#    day  temperature  sale  spend       Tcos  Alaram
# 0    1           34   112     21  18.750000   False
# 1    2           38   220     41  18.636364   False
# 2    3           32   231     24  10.389610   False
# 3    4           31   180     34  18.888889   False
# 4    5           33    21     19  90.476190    True

# %%
del pf["temperature"]

# %%
pf
# Out:
#    day  sale  spend       Tcos  Alaram
# 0    1   112     21  18.750000   False
# 1    2   220     41  18.636364   False
# 2    3   231     24  10.389610   False
# 3    4   180     34  18.888889   False
# 4    5    21     19  90.476190    True

# %%
sale=pf.pop("sale")

# %%
pf
# Out:
#    day  spend       Tcos  Alaram
# 0    1     21  18.750000   False
# 1    2     41  18.636364   False
# 2    3     24  10.389610   False
# 3    4     34  18.888889   False
# 4    5     19  90.476190    True

# %%
pf["ACOS"]=[10,20,30,24,21]

# %%
pf
# Out:
#    day  spend       Tcos  Alaram  ACOS
# 0    1     21  18.750000   False    10
# 1    2     41  18.636364   False    20
# 2    3     24  10.389610   False    30
# 3    4     34  18.888889   False    24
# 4    5     19  90.476190    True    21

# %%
pf["trun"]=pf["day"][:3]

# %%
pf
# Out:
#    day  spend       Tcos  Alaram  ACOS  trun
# 0    1     21  18.750000   False    10   1.0
# 1    2     41  18.636364   False    20   2.0
# 2    3     24  10.389610   False    30   3.0
# 3    4     34  18.888889   False    24   NaN
# 4    5     19  90.476190    True    21   NaN

# %%
pf.insert(1, "bar", pf["ACOS"])

# %%
pf
# Out:
#    day  bar  spend       Tcos  Alaram  ACOS  trun
# 0    1   10     21  18.750000   False    10   1.0
# 1    2   20     41  18.636364   False    20   2.0
# 2    3   30     24  10.389610   False    30   3.0
# 3    4   24     34  18.888889   False    24   NaN
# 4    5   21     19  90.476190    True    21   NaN

# %%
waseem=pd.read_csv("nyc_weather.csv")

# %%
waseem.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
waseem.assign(windhumidity_ratio=lambda x: (x["WindDirDegrees"] / x["Humidity"])).head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees  windhumidity_ratio
# 0             281            5.403846
# 1             275            5.978261
# ...

# %%
In [89]: (
   ....:     waseem.query("DewPoint > 10")
   ....:     .assign(
   ....:         wind_to_Humidity_Ratio=lambda x: x.WindDirDegrees / x.Humidity,
   ....:         wind_to_DewPoint_Ratio=lambda x: x.WindDirDegrees / x.DewPoint,
   ....:     )
   ....:     .plot(kind="scatter", x="wind_to_Humidity_Ratio", y="wind_to_DewPoint_Ratio")
   ....: )
# Out:
# <AxesSubplot:xlabel='wind_to_Humidity_Ratio', ylabel='wind_to_DewPoint_Ratio'>

# %%
waseem[3:7]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
# 5  1/6/2016           33         4        35                 30.50
# 6  1/7/2016           39        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
# 6               10           2.0               0           3    NaN
#
#    WindDirDegrees
# 3             345
# 4             333
# 5             259
# 6             293

# %%
waseem.iloc[4]
# Out:
# EST                     1/5/2016
# Temperature                   20
# DewPoint                      -3
# Humidity                      41
# Sea Level PressureIn       30.57
# VisibilityMiles               10
# WindSpeedMPH                 5.0
# PrecipitationIn                0
# CloudCover                     0
# Events                       NaN
# WindDirDegrees               333
# Name: 4, dtype: object

# %%
waseem.loc[4]
# Out:
# EST                     1/5/2016
# Temperature                   20
# DewPoint                      -3
# Humidity                      41
# Sea Level PressureIn       30.57
# VisibilityMiles               10
# WindSpeedMPH                 5.0
# PrecipitationIn                0
# CloudCover                     0
# Events                       NaN
# WindDirDegrees               333
# Name: 4, dtype: object

# %%
waseem
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
d=1/waseem['Temperature']
d*4
# Out:
# 0     0.105263
# 1     0.111111
# 2     0.100000
# 3     0.160000
# 4     0.200000
# 5     0.121212
# 6     0.102564
# 7     0.102564
# 8     0.090909
# 9     0.080000
# 10    0.121212
# 11    0.114286
# 12    0.153846
# 13    0.133333
# 14    0.093023
# 15    0.085106
# 16    0.111111
# 17    0.160000
# 18    0.181818
# 19    0.125000
# 20    0.129032
# 21    0.153846
# 22    0.153846
# 23    0.142857
# 24    0.117647
# 25    0.093023
# 26    0.097561
# 27    0.108108
# 28    0.111111
# 29    0.117647
# 30    0.086957
# Name: Temperature, dtype: float64

# %%
df[:5].T
# Out:
#                     0         1         2
# day          1/1/2011  1/2/2011  1/3/2011
# termprature        75        65        35
# event             hot       hot     sunny
# action         inhome    inhome   outside

# %%
waseem
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
waseem['Temperature'].mean()
# Out:
# 34.67741935483871

# %%
waseem.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
waseem[['EST','Temperature']][waseem.Temperature==waseem['Temperature'].max()]
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
waseem
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
waseem.set_index('EST',inplace=True)

# %%
waseem
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
waseem.loc['1/15/2016']
# Out:
# Temperature                43
# DewPoint                   31
# Humidity                   62
# Sea Level PressureIn    29.82
# VisibilityMiles             9
# WindSpeedMPH              5.0
# PrecipitationIn             T
# CloudCover                  2
# WindDirDegrees            101
# Name: 1/15/2016, dtype: object

# %%
waseem.reset_index(inplace=True)

# %%
waseem
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
waseem.set_index('WindSpeedMPH',inplace=True)

# %%
waseem
# Out:
#                     EST  Temperature  DewPoint  Humidity  \
# WindSpeedMPH
# 8.0            1/1/2016           38        23        52
# 7.0            1/2/2016           36        18        46
# 8.0            1/3/2016           40        21        47
# 9.0            1/4/2016           25         9        44
# 5.0            1/5/2016           20        -3        41
# 4.0            1/6/2016           33         4        35
# 2.0            1/7/2016           39        11        33
# 4.0            1/8/2016           39        29        64
# 8.0            1/9/2016           44        38        77
# NaN           1/10/2016           50        46        71
# NaN           1/11/2016           33         8        37
# 6.0           1/12/2016           35        15        53
# 10.0          1/13/2016           26         4        42
# 5.0           1/14/2016           30        12        47
# 5.0           1/15/2016           43        31        62
# ...

# %%
waseem.loc[8]
# Out:
#                     EST  Temperature  DewPoint  Humidity  \
# WindSpeedMPH
# 8.0            1/1/2016           38        23        52
# 8.0            1/3/2016           40        21        47
# 8.0            1/9/2016           44        38        77
# 8.0           1/29/2016           36        21        50
#
#               Sea Level PressureIn  VisibilityMiles PrecipitationIn  \
# WindSpeedMPH
# 8.0                          30.03               10               0
# 8.0                          29.86               10               0
# 8.0                          30.16                9               T
# 8.0                          29.58               10               0
#
#               CloudCover  WindDirDegrees
# WindSpeedMPH
# 8.0                    5             281
# 8.0                    1             277
# 8.0                    8              76
# 8.0                    4             298
